# %%
## Imports
import pandas as pd
import numpy as np
import time
import re

import spacy
from collections import Counter

np.random.seed(3000)

print("Imports completed")
# Out:
# Imports completed

# %%
LANGUAGE = 'ger'
SOURCE_DATASET = 'DEPlain'

OUTPUT_DATASET_SIZE = 5000
NUM_OF_CANDIDATE_SETS = 10

SHORT_OUTPUT_DATASET_SIZE = 200

filter_out_problematic_instances = True
clean_up = True
measure_syntactic_diversity = True
measure_lexical_diversity = True


execution_start_time = time.time()
execution_start_time_string = time.strftime("%m_%d_%Hh")

output_file_name = "data_subset_" + LANGUAGE + "_" + str(OUTPUT_DATASET_SIZE) + "_from_" + SOURCE_DATASET + "_" + execution_start_time_string
print("Output file name is going to be: ", output_file_name)
# Out:
# Output file name is going to be:  data_subset_ger_5000_from_DEPlain_09_05_17h

# %%
## Get the aligned sentences

source_file = '../../../datasets_original/DEPlain/E__Sentence-level_Corpus/DEplain-APA-sent/all.csv'
original_df = pd.read_csv(source_file)
original_df.head()
# Out:
#                                             original  \
# 0  Am Mittwoch hat der Iran bekanntgegeben, dass ...
# 1  Die Präsidentin der EU-Kommission, Ursula von ...
# 2  So sollen die Treibhaus-Gase in der EU bis zum...
# 3  In den letzten 29 Jahren schaffte man eine Ver...
# 4    Für das neue Ziel bleiben weniger als 10 Jahre.
#
#                                       simplification original_id  \
# 0  Der Iran wird teilweise aus dem Atom-Abkommen ...   296-1-1-0
# 1  Brüssel Ursula von der Leyen ist die Präsident...   628-1-1-0
# 2  Bis zum Jahr 2030 soll es in der EU um 55 Proz...   628-1-1-2
# 3  Das ist sehr viel, denn in den letzten 29 Jahr...   628-1-1-3
# 4  Für das neue Ziel bleiben aber weniger als 10 ...   628-1-1-4
#
#                simplification_id  pair_id domain            corpus  \
# 0                      296-0-1-0      296   news  News Science APA
# 1  628-0-1-0|628-0-1-1|628-0-1-2      628   news  News Science APA
# 2                      628-0-1-4      628   news  News Science APA
# 3                      628-0-1-5      628   news  News Science APA
# 4                      628-0-1-6      628   news  News Science APA
#
#   language_level_original language_level_simple   license  \
# 0                      b1                    a2  save_use
# 1                      b1                    a2  save_use
# 2                      b1                    a2  save_use
# 3                      b1                    a2  save_use
# 4                      b1                    a2  save_use
#
#                             author  \
# 0  APA - Austria Presse Agentur eG
# 1  APA - Austria Presse Agentur eG
# 2  APA - Austria Presse Agentur eG
# 3  APA - Austria Presse Agentur eG
# 4  APA - Austria Presse Agentur eG
#
#                                           simple_url  \
# 0  https://science.apa.at/nachrichten-leicht-vers...
# 1  https://science.apa.at/nachrichten-leicht-vers...
# 2  https://science.apa.at/nachrichten-leicht-vers...
# 3  https://science.apa.at/nachrichten-leicht-vers...
# 4  https://science.apa.at/nachrichten-leicht-vers...
#
#                                          complex_url  \
# 0  https://science.apa.at/nachrichten-leicht-vers...
# 1  https://science.apa.at/nachrichten-leicht-vers...
# 2  https://science.apa.at/nachrichten-leicht-vers...
# 3  https://science.apa.at/nachrichten-leicht-vers...
# 4  https://science.apa.at/nachrichten-leicht-vers...
#
#                                         simple_title  \
# 0  Nachrichten leicht verständlich (in der Sprach...
# 1  Nachrichten leicht verständlich (in der Sprach...
# 2  Nachrichten leicht verständlich (in der Sprach...
# 3  Nachrichten leicht verständlich (in der Sprach...
# 4  Nachrichten leicht verständlich (in der Sprach...
#
#                                        complex_title access_date  rater  \
# 0  Nachrichten leicht verständlich (in der Sprach...  2021-04-20      1
# 1  Nachrichten leicht verständlich (in der Sprach...  2021-04-20      1
# 2  Nachrichten leicht verständlich (in der Sprach...  2021-04-20      1
# 3  Nachrichten leicht verständlich (in der Sprach...  2021-04-20      1
# 4  Nachrichten leicht verständlich (in der Sprach...  2021-04-20      1
#
#   alignment
# 0       1:1
# 1       1:3
# 2       1:1
# 3       1:1
# 4       1:1

# %%
my_column = original_df["alignment"]

percentage = my_column.value_counts(normalize=True) * 100
print(percentage.head(10))
# Out:
# 1:1    75.537266
# 1:2    15.759793
# 2:1     2.766347
# 2:2     2.362445
# 1:3     1.836610
# 2:3     0.617284
# 1:4     0.312452
# 3:2     0.182899
# 2:4     0.167657
# 3:1     0.121933
# Name: alignment, dtype: float64

# %%
relevant_df = original_df.copy()

# %%
if filter_out_problematic_instances:

    def has_multiple_sentences(text):
        # Match sentence-ending punctuation followed by a space and a capital letter (basic sentence structure)
        return bool(re.search(r'[.!?]\s+[A-ZÀ-Ý]', text))

    def contains_artifacts(text):   ## do not call for French
        # Define a regex pattern to match common artifact patterns
        # This pattern checks for unusual characters or sequences that are likely artifacts
        artifact_pattern = re.compile(r'[^\x20-\x7E]')  # Matches non-printable or unusual ASCII characters
        return bool(artifact_pattern.search(text))
            
    def contains_many_digits(text, threshold_base=5, threshold_increment=0.1):
        threshold = threshold_base + threshold_increment * len(text)
        digits = len(re.findall(r'\d', text))
        return digits > threshold
    
    def contains_many_special_chars(text, threshold_base=3, threshold_increment=0.1):
        threshold = threshold_base + threshold_increment * len(text)
        # Regex to match any character that is not a letter, digit, or common punctuation, including French accented characters
        special_chars = len(re.findall(r'[^a-zA-Z0-9\sÀ-ž]', text))
        return special_chars > threshold
    
    
    
    
    filtered_indices = []
    counter = 0
    sents_w_artifacts = 0
    sents_w_many_spec_chars = 0
    sents_w_many_digits = 0
    sents_that_are_multiple_sents = 0
    
    
    # Iterate over the DataFrame and find rows with artifacts
    for index, row in relevant_df.iterrows():
        sentence = row['original']
        counter += 1

        if has_multiple_sentences(sentence):
            sents_that_are_multiple_sents += 1
            filtered_indices.append(index)
            if counter % 30 == 0:
                print("|| Found multiple sentences in instance " + str(index) + " ||")
                print(sentence)

        elif contains_many_digits(sentence):
            sents_w_many_digits += 1
            filtered_indices.append(index)
            if counter % 20 == 0:
                print("|| Too many digits in instance " + str(index) + " ||")
                print(sentence)

            
        else:
            if contains_many_special_chars(sentence):
                sents_w_many_spec_chars += 1
                filtered_indices.append(index)
                if counter % 10 == 0:
                    print("|| Too many special characters in instance " + str(index) + " ||")
                    print(sentence)         
            
            
    
    # Create a new DataFrame excluding the rows with artifacts
    clean_df = relevant_df.drop(index=filtered_indices)
    df = clean_df
    
    print("Filtering complete")
    #print("Filtered out ", sents_w_artifacts, " sentences containing artifacts.")
    print("Filtered out ", sents_that_are_multiple_sents, " instances with multiple sentences.")
    print("Then filtered out ", sents_w_many_digits, " sentences containing many digits.")
    print("Then filtered out ", sents_w_many_spec_chars, " sentences containing too many special characters.")
# Out:
# || Found multiple sentences in instance 149 ||
# Manches wurde aber auch billiger. Am stärksten sank der Preis bei Kaffee. Auch Bekleidung und Schuhe wurden billiger.
# || Found multiple sentences in instance 299 ||
# Mutter und Kind geht es sehr gut, erzählte Prinz Harry. Er war bei der Geburt dabei.
# || Found multiple sentences in instance 449 ||
# Am Dienstag haben Sänger von 17 Ländern im 1. Halbfinale von dem Musik-Wettbewerb gesungen.
# || Found multiple sentences in instance 809 ||
# Im Jahr 1989 kam es in China zu großen Demonstrationen. Hunderttausende Menschen demonstrierten wochenlang auf dem Tiananmen-Platz in Peking.
# || Found multiple sentences in instance 1229 ||
# Der wärmste See ist der Stubenbergsee in der Steiermark. Er ist 27 Grad warm.
# || Found multiple sentences in instance 1439 ||
# Am Montag ist Kyriakos Mitsotakis als griechischer Minister-Präsident vereidigt worden. Mitsotakis ist der Anführer der Partei Nea Dimokratia.
# || Found multiple sentences in instance 1529 ||
# Weil es in den Sommer-Monaten meistens sehr heiß ist, trinken die Menschen mehr, auch mehr alkoholische Getränke. Deshalb gibt es dann mehr Unfälle.
# || Found multiple sentences in instance 1799 ||
# Alle diese Politiker sind sogenannte Brexit-Hardliner. Das heißt sie wollen den Brexit unbedingt.
# || Found multiple sentences in instance 2519 ||
# Am 10. September ist der Welttag der Selbstmord-Prävention.
# || Found multiple sentences in instance 2729 ||
# Reinhold Messner ist ein sehr berühmter Bergsteiger aus Südtirol. Südtirol liegt in Italien.
# || Found multiple sentences in instance 2849 ||
# Dabei trug Schwarzenegger eine kurze Lederhose. Das ist die typische Tracht für das Oktoberfest.
# || Found multiple sentences in instance 3269 ||
# In der Qualifikation für die EM hat am Donnerstag die österreichische Nationalmannschaft gegen Israel in Wien gespielt. Dabei gewann Österreich mit 3:1.
# || Found multiple sentences in instance 3389 ||
# Die Kurden haben im Krieg in Syrien ein großes Gebiet im Norden von Syrien erobert. Dieses Gebiet grenzt an die Türkei. Jetzt fürchtet die Türkei, dass die Kurden in der Türkei ein eigenes Land gründen.
# || Found multiple sentences in instance 3509 ||
# Um in der Champions League weiterzukommen, muss Salzburg das Rück-Spiel gegen Napoli am 5. November wahrscheinlich gewinnen.
# || Found multiple sentences in instance 3959 ||
# Mit dem Budget sollen viele Bereiche unterstützt werden. Der EU ist vor allem der Klima-Schutz und der Kampf gegen die Jugend-Arbeitslosigkeit wichtig.
# || Found multiple sentences in instance 4529 ||
# Bei einer Grippe wird man aber sehr schnell viel schwerer krank als bei einer Verkühlung. Meistens hat man bei einer Grippe hohes Fieber.
# || Found multiple sentences in instance 4709 ||
# Das Baby kam am 18. Dezember auf die Welt.
# || Found multiple sentences in instance 4739 ||
# Seit dem 1. Jänner 1990 bekommen Autos in Österreich weiße Nummern-Tafeln.
# || Found multiple sentences in instance 5129 ||
# Dann muss das EU-Parlament den Vertrag noch genehmigen. Danach müssen die 27 EU-Länder noch einmal schriftlich zustimmen.
# || Found multiple sentences in instance 5249 ||
# Am Mittwoch hat es auf einem Grundstück in Oberösterreich bereits zum 4. Mal innerhalb von nur 8 Tagen gebrannt.
# || Found multiple sentences in instance 5339 ||
# Österreich ist seit 1. Jänner 1995 Mitglied der EU.
# || Found multiple sentences in instance 5729 ||
# Noch bis zum 25. Februar kann man Namens-Vorschläge an den Zoo schicken.
# || Found multiple sentences in instance 7079 ||
# Von den 6 bis 14 Jahre alten Kindern werden nicht einmal ein Prozent an den Schulen betreut. Der Rest der Kinder ist noch immer zu Hause.
# || Found multiple sentences in instance 7289 ||
# Dieser Fall war bereits der 3. Fenstersturz in Wien in rund einer Woche.
# || Found multiple sentences in instance 7739 ||
# Der Wiener Tiergarten Schönbrunn öffnet am 15. Mai nach rund 2 Monaten Corona-Pause wieder.
# || Found multiple sentences in instance 8369 ||
# Mehr als die Hälfte der flüchtenden Menschen sind sogenannte "Binnen-Flüchtlinge". Das heißt, dass sie im eigenen Land oder in der eigenen Region auf der Flucht sind.
# || Found multiple sentences in instance 8519 ||
# Wien/New York - Vor genau 75 Jahren ist die UNO gegründet worden. Am 26. Juni 1945 unterzeichneten 50 Staaten die UNO-Charta, in der die Rechte und Pflichten der Mitglieds-Länder stehen.
# || Found multiple sentences in instance 8579 ||
# Sie erinnert gleichzeitig daran, dass viele Schüler weitere Funktionen und unterstützende Technologien benötigen. Zum Beispiel Schüler, die sich sprachlich nicht so gut mitteilen können.
# || Found multiple sentences in instance 9149 ||
# Vor allem im Tourismus ist die Arbeitslosigkeit besonders stark gestiegen. Heuer gab es Ende Juli im Tourismus 73,8 Prozent mehr Arbeitslose als im Vorjahr.
# || Found multiple sentences in instance 9269 ||
# Am Wochenende haben sich Politiker aus rund 30 Ländern bei einer Online-Konferenz auf ein Hilfspaket geeinigt. Der Libanon soll 252,7 Millionen Euro Soforthilfe bekommen.
# || Found multiple sentences in instance 9479 ||
# Aus dem Streit entwickelte sich eine Rauferei. Die beiden Männer fielen dabei zwischen 2 geparkte Autos.
# || Found multiple sentences in instance 10109 ||
# Sie kann zum Beispiel ausrechnen, wie viele Menschen in Österreich leben. Sie kann aber auch ausrechnen, wie viel Geld die Menschen in Österreich im Durchschnitt verdienen oder wie die Wirtschaft in Österreich läuft.
# || Found multiple sentences in instance 11069 ||
# Damit alle Pakete rechtzeitig bis 24. Dezember ankommen, soll man sie bis spätestens 21. Dezember aufgeben.
# || Found multiple sentences in instance 11249 ||
# Boseman starb am 28. August mit nur 43 Jahren an Darmkrebs.
# || Found multiple sentences in instance 11429 ||
# Auch in Niederösterreich gibt es mehr Möglichkeiten für Corona-Tests. An den 5 Test-Stationen in Amstetten, Korneuburg, St. Pölten, Wiener Neustadt und Zwettl gibt es statt 10 nun 21 Test-Straßen.
# || Found multiple sentences in instance 11639 ||
# Der Impfstoff von Biontech und Pfizer wurde am 21. Dezember als erster Corona-Impfstoff in der EU zugelassen.
# || Found multiple sentences in instance 12599 ||
# Die Fußball-EM findet heuer von 11. Juni bis 11. Juli statt.
# Filtering complete
# Filtered out  1168  instances with multiple sentences.
# Then filtered out  9  sentences containing many digits.
# Then filtered out  1  sentences containing too many special characters.

# %%
print(len(relevant_df))
print(len(clean_df))
print(len(relevant_df)-len(clean_df))
print(len(clean_df)/len(relevant_df))
# Out:
# 13122
# 11944
# 1178
# 0.910227099527511

# %%
if clean_up:

    def replace_LRB_RRB(text):
        # Replace "-LRB-" with "(" and "-RRB-" with ")"
        text = text.replace('-LRB- ', '(')
        text = text.replace(' -RRB-', ')')
        return text

    def replace_wrong_quotation_marks(text):
        # Replace patterns like `` word(s) '' with "word(s)"
        return re.sub(r'``\s*(.*?)\s*\'\'', r'"\1"', text)
    
    def remove_spaces_before_punctuation_FRENCH(text):
        # Regex pattern to match a space between a word-like string and a period or comma.
        return re.sub(r'(\w)\s+([.,\'])', r'\1\2', text)


    df['wiki_sent'] = df['original'].apply(replace_LRB_RRB)
    #df['wiki_sent'] = df['wiki_sent'].apply(replace_wrong_quotation_marks)
    df['wiki_sent'] = df['original'].apply(remove_spaces_before_punctuation_FRENCH)
    
    print("Clean up performed.")

else:
    print("No clean up")
# Out:
# Clean up performed.

# %%
counter = 0
for sentence in df['original']:
    counter += 1
    if counter % 100 == 0:
        print(sentence)
# Out:
# Winterreifen-Pflicht ab Donnerstag vorüber.
# Seitdem gab es jedes Jahr mehr als 500.000 Anzeigen.
# Dieses Geld nennt man Mindestsicherung.
# Der Iran durfte zum Beispiel nicht mehr so viel Öl an andere Länder verkaufen wie zuvor.
# Am Montag ist der ehemalige österreichische Formel-1-Rennfahrer Niki Lauda gestorben.
# Schüler protestierten wieder für mehr Klima-Schutz.
# Auf dem Ausflugsboot waren viele Urlauber aus Südkorea.
# An diesem Tag landeten alliierte Truppen in der Normandie.
# Davon waren mehr als 43.000 Buben und mehr als 41.000 Mädchen.
# In China gibt es eine Gegend, die Sichuan heißt.
# Und ein weiterer Orang-Utan wirft die Wanne so oft um, bis er komplett nass ist.
# Die Polizei geht davon aus, dass der Mann wahrscheinlich mit einem Ast tödlich am Kopf verletzt wurde.
# Sein Rekord liegt sogar bei 74 Hotdogs.
# Dabei sterben immer wieder Menschen, zum Beispiel weil ihre Boote untergehen.
# Die Komodo-Warane sollen einfach zu Fuß von ihrem alten Gehege übersiedeln.
# Jetzt hat das Mädchen auch einen Namen, es heißt Kibali.
# Das Foto bekommt die Sozial-Versicherung nämlich von anderen Behörden.
# Die Amok-Läufe passierten in den US-Staaten Texas und Ohio.
# Andere Fußball-Mannschaften müssen sich in einem vorherigen Bewerb noch qualifizieren.
# Extremismus ist eine Art, wie man über die Politik und die Gesellschaft denkt.
# Seit Mittwoch kann man in Österreich das Klima-Volksbegehren unterschreiben.
# Der "Falter" soll nicht mehr schreiben dürfen, dass die ÖVP mehr Geld ausgibt als sie darf oder dass sie geheime Kassen hat.
# Sie können dann nur schwer in ein Gebäude kommen.
# Brexit-Streit in Großbritannien verschärft sich.
# Dem Affen-Baby und seiner Mutter geht es gut.
# Lionel Messi wieder zum Weltfußballer gewählt.
# Die Zahlen werden sich aber noch leicht ändern.
# Hass-Postings sind Einträge im Internet, die voll mit Hass sind.
# Einen Nobelpreis gibt es für Physik, Chemie, Medizin, Literatur und für Bemühungen um den Frieden in der Welt.
# Es kann sein, dass auch diese Menschen nicht überlebt haben.
# Dabei trug Naruhito ein besonderes braunes Gewand.
# Seinen 11 Monate alten Sohn versuchte er zu ersticken.
# Bei der Nationalratswahl im September ist die ÖVP die stärkste Partei geworden.
# Einige Zeitungen berichteten nämlich, dass die Urlauber an einem Fluss übernachteten.
# Morales erklärte sich zum Sieger, aber die Opposition warf ihm Wahlbetrug vor.
# Er wurde erstochen, als er gerade einen Vortrag hielt.
# Im Tiergarten Schönbrunn in Wien hat es Nachwuchs bei den Eisbären gegeben.
# USA wollen Straf-Zölle auf Waren aus Frankreich einführen.
# Die meisten Franzosen unterstützen deshalb die Proteste und Streiks.
# Die Abgeordneten heißen Karl Baron, Klaus Handler und Dietrich Kops.
# Busch-Brände in Australien wegen großer Hitze kaum zu löschen.
# China kauft Schweinefleisch und technische Produkte aus den USA und aus der EU.
# Sie wollen sich sehr stark für den Umweltschutz einsetzen.
# Am nächsten Tag wanderte er weiter.
# Aber auch Besuche in Restaurants und Hotels wurden teurer.
# Dieser Virus löst eine Lungen-Krankheit aus.
# Bei weiblichen Küken ist das anders, da diese als erwachsene Hühner dann Eier legen.
# Der Brexit-Vertrag sorgt für einen geordneten Brexit.
# Bisher hatte der Staat meistens ein Budget-Defizit, das heiß er gab mehr Geld aus als er einnahm.
# Viele Küken starben bei einem Bauernhof-Brand in Oberösterreich.
# Wien - Seit Montag gibt es eine eigene Hotline für die Mathematik-Matura.
# Damit starben in China bisher mehr als 2.200 Menschen und mehr als 75.000 Menschen sind an dem Virus erkrankt.
# Kunden in Österreich sind über Mogel-Packungen verärgert.
# Die Weltbank hat schon bei anderen Krankheiten Länder mit Hilfe von Geld unterstützt.
# Aus Erdöl macht man zum Beispiel Treibstoffe wie Benzin und Diesel oder auch Heizöl.
# Auch Banken, Post-Filialen und die öffentlichen Verkehrs-Mittel bleiben offen.
# Paris/Brüssel - Wegen des Corona-Virus schließt die EU ihre Außen-Grenzen und lässt niemand mehr einreisen.
# Dafür werden auch Drohnen eingesetzt.
# Im Körper werden die Viren mehr und beschädigen die Zellen.
# Das hat Bildungs-Minister Heinz Faßmann am Dienstag angekündigt.
# Tennis-Turnier in Wimbledon abgesagt.
# Diese Patienten können oft nicht mehr alleine atmen und brauchen dafür eine spezielle Maschine.
# Nach Ostern öffnen auch wieder kleine Geschäfte sowie Baumärkte und Gartenmärkte.
# Diese App heißt "Stopp Corona".
# In den Geschäften gilt aber weiter Masken-Pflicht.
# Tom Hanks schrieb dem Buben zurück.
# Das hat Gesundheits-Minister Rudolf Anschober erklärt.
# Seit Freitag haben Sportstätten zum Teil wieder geöffnet.
# Eine Entscheidung soll es noch diese Woche geben.
# Allerdings gibt es nun Regeln in den Messen, damit sich niemand mit dem Corona-Virus ansteckt.
# Im Post-Zentrum Hagenbrunn in Niederösterreich haben sich 63 Mitarbeiter angesteckt, die in Wien wohnen.
# Am Freitag sollen nun auch die Innen-Bereiche für Besucher geöffnet werden.
# Eine Hälfte der Schulklasse hat zum Beispiel von Montag bis Mittwoch Unterricht, die andere Hälfte am Donnerstag und Freitag.
# Fahrbahnen waren teilweise bis zu einem Meter hoch verschüttet.
# Das hat Landwirtschafts-Ministerin Elisabeth Köstinger angekündigt.
# Besonders in Brasilien hat der Corona-Virus viele Menschen getroffen.
# Schon im nächsten Jahr soll die österreichische Wirtschaft wieder wachsen, und zwar um 4 bis 6 Prozent.
# Die Menschen arbeiteten in einer Jade-Mine in der Ortschaft Hpakant.
# Der Bärenschützklamm ist nun für Wanderer gesperrt.
# Van der Bellen lobte, dass es nun weniger Reise-Beschränkungen gibt.
# Auch die übrigen 7 FPÖ-Bezirksräte von Hietzing sind aus der FPÖ ausgetreten.
# In Australien hat es 2019 und 2020 viele große Brände gegeben.
# Davon geht derzeit das Bildungs-Ministerium aus.
# Dabei gewann der bisherige Präsident Alexander Lukaschenko.
# Nun hat Bildungsminister Heinz Faßmann gesagt, dass er ab Herbst wieder einen normalen Betrieb an den Schulen haben will.
# Unter Präsident Trump gibt es zu viel Wut, zu viel Angst, zu viel Spaltung.
# Das Ältere ist mittlerweile in einem Zoo in Deutschland.
# Russischer Politiker Nawalny wurde vergiftet.
# Der Grund dafür könnte sein, dass sich einige Flüchtlinge in dem Lager mit dem Corona-Virus angesteckt haben.
# Corona-Ampel steht in Wien auf Orange.
# Der Wiener Opernball im nächsten Jahr findet nicht statt.
# Arbeitslosigkeit in Österreich leicht gestiegen.
# Trump war 3 drei Tage lang im Krankenhaus wegen einer Corona-Infektion behandelt worden.
# Fast 690 Millionen Menschen weltweit sind unterernährt.
# Dieser Mensch soll in der Nähe des Flughafens in 1.800 Metern Höhe unterwegs gewesen sein.
# Bei dem Vogel handelt es sich um eine Pfuhlschnepfe.
# Man darf sich nur mehr Essen von Lokalen abholen oder liefern lassen.
# Am Montag hat es in Österreich eine Razzia gegen islamistische Organisationen wie die Muslimbruderschaft und die Hamas gegeben.
# Der französische Regierungs-Chef Jean Castex und die Bürgermeisterin von Paris, Anne Hidalgo, kamen zu Gedenkfeiern in Paris und im Pariser Vorort Saint-Denis.
# Das Distance Learning funktioniert bei diesem Lockdown deutlich besser als beim ersten Lockdown.
# Noch ist aber nicht klar, wie das konkret ablaufen soll.
# Rapid hatte keine Chance und verlor mit 1:4.
# Auch Bewohner von Altersheimen und Pflegeheimen sollen als erste geimpft werden.
# Alaba ist Österreichs Fußballer des Jahres 2020.
# Auf Wikileaks wurden viele geheime Dokumente der USA über die Kriege im Irak und Afghanistan veröffentlicht.
# Die USA haben bereits China vorgeworfen, nicht ganz ehrlich über den Virus-Ausbruch informiert zu haben.
# Die fehlende Lieferung soll im Februar nachgeholt werden.
# Vor allem in den 1970er Jahren war er mit Liedern im Dialekt erfolgreich.
# Durch die Corona-Maßnahmen gibt es erstmals seit Jahrzehnten keine Grippefälle in Österreich.
# Das geht aus Daten der Statistik Austria hervor.
# Durch die hohe Nachfrage war der Drive-In der Test-Station beim Austria Center in Wien von Samstag bis Montag ausgebucht.
# Mehr als eine Stunde lang konnten Kunden zum Beispiel das WLAN nicht benutzen.
# Am Donnerstag haben diese Unternehmen in einer Online-Veranstaltung verschiedene Sicherheitskonzepte vorgestellt.
# Jetzt prüft die zuständige Behörde in einem extra schnellen Verfahren die mögliche Zulassung.
# Dabei trat gefährliche radioaktive Strahlung aus und viele Menschen mussten die Gegend verlassen.
# Weltweit wird derzeit gegen das Corona-Virus geimpft.
# Die Ausgangs-Beschränkungen gelten dann nicht nur in der Nacht sondern auch tagsüber.
# Es gab also weniger Möglichkeiten Geld auszugeben.
# Die Gletscher in Österreich haben viel Eis verloren.

# %%
def get_dependency_tree(doc):
    # Get the dependency structure in terms of (head, relation, dependent)
    return [(token.head.dep_, token.dep_, token.dep_) for token in doc if token.head != token]

def calculate_tree_diversity(parse_trees):
    # Flatten the list of trees and count unique structures
    flattened_trees = [tuple(tree) for trees in parse_trees for tree in trees]
    tree_counter = Counter(flattened_trees)
    
    # Diversity score: higher score means more unique structures
    diversity_score = len(tree_counter) / sum(tree_counter.values())
    
    return diversity_score

# %%
# Load the German model
nlp = spacy.load("de_core_news_lg")

candidate_sets = [df["original"].sample(n=OUTPUT_DATASET_SIZE, replace=False) for _ in range(NUM_OF_CANDIDATE_SETS)]

sets_w_scores = []

start_time_all = time.time()

for idx, candidate_set in enumerate(candidate_sets):

    start_time = time.time()

    print("Assessing set ", idx+1, "/", NUM_OF_CANDIDATE_SETS, " of len ", OUTPUT_DATASET_SIZE)

    # List of sentences
    sentences = candidate_set

    print(type(sentences))

    # Parse the sentences
    docs = [nlp(sentence) for sentence in sentences]

    print(len(docs))

    tree_diversity_score = None
    std_clause_density_avg = None
    std_token_prob_avg = None



    if measure_syntactic_diversity:
        # Extract parse trees for all sentences
        parse_trees = [get_dependency_tree(doc) for doc in docs]
    
        elapsed_time_trees = time.time() - start_time
        print("Done with the parse_trees after ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time_trees)) + f".{int((elapsed_time_trees % 1) * 1000):03d}")
    
        # Calculate syntactic diversity score
        
        tree_diversity_score = calculate_tree_diversity(parse_trees)

    
        clause_density_avg_list = []
        for doc in docs:
            num_tokens = len([token for token in doc if token.is_alpha])
            num_clauses = sum(1 for token in doc if token.dep_ in ('ROOT', 'csubj', 'csubjpass', 'advcl', 'relcl', 'xcomp', 'ccomp'))
            clause_density = num_clauses / num_tokens if num_tokens else 0
            clause_density_avg_list.append(clause_density)
        
        std_clause_density_avg = np.std(clause_density_avg_list)

    if measure_lexical_diversity:
        token_prob_avg_list = []
        for doc in docs:
            # Calculate lexical diversity
            token_freqs = [token.prob for token in doc if token.is_alpha]  # Use token.prob as a proxy for frequency score
            token_prob_avg = np.mean(token_freqs) if token_freqs else 0
            token_prob_avg_list.append(token_prob_avg)
        
        std_token_prob_avg = np.std(token_prob_avg_list)
        
    
    sets_w_scores.append((idx, tree_diversity_score, std_clause_density_avg, std_token_prob_avg))
    
    elapsed_time_set = time.time() - start_time
    print("Finished set ",idx, "after ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time_set)) + f".{int((elapsed_time_set % 1) * 1000):03d}")

elapsed_time_all = time.time() - start_time_all
print("Finished all after ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time_all)) + f".{int((elapsed_time_all % 1) * 1000):03d}")
print(sets_w_scores)
# Out:
# Assessing set  1 / 10  of len  5000
# <class 'pandas.core.series.Series'>
# 5000
# Done with the parse_trees after  00:00:35.060
# Finished set  0 after  00:00:35.265
# Assessing set  2 / 10  of len  5000
# <class 'pandas.core.series.Series'>
# 5000
# Done with the parse_trees after  00:00:36.310
# Finished set  1 after  00:00:36.547
# Assessing set  3 / 10  of len  5000
# <class 'pandas.core.series.Series'>
# 5000
# Done with the parse_trees after  00:00:44.829
# Finished set  2 after  00:00:45.105
# Assessing set  4 / 10  of len  5000
# <class 'pandas.core.series.Series'>
# 5000
# Done with the parse_trees after  00:00:37.829
# Finished set  3 after  00:00:38.094
# Assessing set  5 / 10  of len  5000
# <class 'pandas.core.series.Series'>
# 5000
# Done with the parse_trees after  00:00:42.095
# Finished set  4 after  00:00:42.330
# Assessing set  6 / 10  of len  5000
# <class 'pandas.core.series.Series'>
# 5000
# Done with the parse_trees after  00:00:36.828
# Finished set  5 after  00:00:37.140
# Assessing set  7 / 10  of len  5000
# <class 'pandas.core.series.Series'>
# 5000
# Done with the parse_trees after  00:00:44.350
# Finished set  6 after  00:00:44.666
# Assessing set  8 / 10  of len  5000
# <class 'pandas.core.series.Series'>
# 5000
# Done with the parse_trees after  00:00:36.294
# Finished set  7 after  00:00:36.544
# Assessing set  9 / 10  of len  5000
# <class 'pandas.core.series.Series'>
# 5000
# Done with the parse_trees after  00:00:38.096
# Finished set  8 after  00:00:38.325
# Assessing set  10 / 10  of len  5000
# <class 'pandas.core.series.Series'>
# 5000
# Done with the parse_trees after  00:00:39.468
# Finished set  9 after  00:00:39.701
# Finished all after  00:06:33.724
# [(0, 0.006139466691102355, 0.06531860268535505, 0.0), (1, 0.006128164096595869, 0.0628229167878242, 0.0), (2, 0.00625527387460102, 0.06040390156658362, 0.0), (3, 0.006271827972718463, 0.06016376294800875, 0.0), (4, 0.0061021284370147075, 0.061229153996163556, 0.0), (5, 0.005992413274936319, 0.06092302118970018, 0.0), (6, 0.006057519145762465, 0.06386254888542288, 0.0), (7, 0.006089978054133138, 0.06053383551586649, 0.0), (8, 0.006053180205552101, 0.057868895723378035, 0.0), (9, 0.00612143605580985, 0.05939437063894369, 0.0)]

# %%
# Weights
weights = [0.3, 0.3, 0.4]

# Function to calculate the weighted sum for a tuple
def weighted_sum(tup):
    return weights[0] * tup[1] + weights[1] * tup[2] + weights[2] * tup[3]

# Find the tuple with the maximum weighted sum
best_tuple = max(sets_w_scores, key=weighted_sum)

print(sets_w_scores)
print(best_tuple)
# Out:
# [(0, 0.006139466691102355, 0.06531860268535505, 0.0), (1, 0.006128164096595869, 0.0628229167878242, 0.0), (2, 0.00625527387460102, 0.06040390156658362, 0.0), (3, 0.006271827972718463, 0.06016376294800875, 0.0), (4, 0.0061021284370147075, 0.061229153996163556, 0.0), (5, 0.005992413274936319, 0.06092302118970018, 0.0), (6, 0.006057519145762465, 0.06386254888542288, 0.0), (7, 0.006089978054133138, 0.06053383551586649, 0.0), (8, 0.006053180205552101, 0.057868895723378035, 0.0), (9, 0.00612143605580985, 0.05939437063894369, 0.0)]
# (0, 0.006139466691102355, 0.06531860268535505, 0.0)

# %%
best_set_of_sentences = candidate_sets[best_tuple[0]]
print(best_set_of_sentences)
# Out:
# 9412              Der Mann wurde dann ins Spital gebracht.
# 5185     Mit der 1-2-3-Karte soll man in Zukunft für al...
# 10329    Zusammen mit dem Friedens-Nobelpreis bekommt d...
# 1178          Boris Johnson droht mit einem harten Brexit.
# 11229    Der Käufer will für die Öffentlichkeit unerkan...
#                                ...
# 659        Strache zeigt 3 Personen wegen Ibiza-Videos an.
# 6951     In öffentlichen Verkehrsmitteln und in Taxis g...
# 10462    Die Autofahrer sollen dann also nur noch 30 km...
# 575      Die Regierung von Österreich hat nach der Regi...
# 12313    Sie sind damit vermutlich besser vor einer ern...
# Name: original, Length: 5000, dtype: object

# %%
with open(output_file_name, "w") as file:
    counter = 0
    for index, sentence in best_set_of_sentences.items():
        counter += 1
        file.write(f"{index}|{sentence}\n\n")
        if counter % 50 == 0:
            print(f"{index}|{sentence}\n\n")
# Out:
# 5430|49 Prozent der befragten US-Bürger sind zufrieden mit seiner Arbeit als Präsident.
#
#
# 5457|Danach brach das Flugzeug in mehrere Teile und geriet teilweise in Brand.
#
#
# 4827|Nun gibt es einen neuen Generalsekretär.
#
#
# 8683|Dritter wurde überraschend der McLaren-Fahrer Lando Norris.
#
#
# 6243|Das heißt, er kann bei Menschen oder Tieren Krankheiten auslösen.
#
#
# 8953|Auch das war laut VfGH gesetzwidrig, weil nicht alle Geschäfte gleich behandelt wurden.
#
#
# 5044|Beim Welt-Wirtschafts-Forum treffen sich Politiker, Firmen-Chefs und Wissenschafter aus der ganzen Welt und sprechen über verschiedene Themen.
#
#
# 6397|Es gab bis Freitag zwar 39 neu angesteckte Menschen.
#
#
# 3806|Am Sonntag hatten schon die Grünen entschieden, dass sie mit der ÖVP über eine Regierungs-Bildung verhandeln wollen.
#
#
# 12121|Daher fordert die Arbeiterkammer eine Soforthilfe von 200 Euro pro Schulkind zur Familienbeihilfe.
#
#
# 2538|Für sie werden extra Rampen gebaut.
#
#
# 3334|Nun hat der Verfassungs-Gerichtshof entschieden, die Klage gar nicht anzunehmen.
#
#
# 984|Das am meisten verkaufte Elektro-Auto war der Renault Zoe.
#
#
# 5432|Fast 500 Tote in China durch Corona-Virus.
#
#
# 12515|Bei dem Unfall prallten ein Geländewagen und ein Lastwagen auf einer Kreuzung zusammen.
#
#
# 4963|In diesem Teil des Kongresses haben aber die Republikaner die Mehrheit.
#
#
# 7882|Mayer hat schon früher im Bereich Kunst und Kultur gearbeitet.
#
#
# 3290|Bei einer Schlamm-Lawine rutscht eine riesige Menge Schlamm ab.
#
#
# 10917|Die Menschen dürfen das Haus nur für bestimmte Zwecke verlassen.
#
#
# 6341|Es starben 2 Personen in der Steiermark, 1 Person in Oberösterreich und 1 Person in Niederösterreich.
#
#
# 7338|Es gilt aber weiterhin, dass man in der Öffentlichkeit 1 Meter Abstand zu anderen Menschen halten muss.
#
#
# 8471|Das gilt auch für Mannschafts-Sportarten wie Fußball und Kampf-Sportarten wie Judo oder Karate.
#
#
# 1876|Zum Beispiel von den Behörden, von denen man seinen Reisepass bekommt.
#
#
# 9601|Besonders schlimm ist die Situation bei den Karotten und Tomaten.
#
#
# 3612|Bei Verstößen gegen das Rauchverbot müssen die Lokal-Besitzer Strafen zahlen.
#
#
# 9228|Am Freitag wird es überall sonnig und 27 bis 32 Grad heiß werden.
#
#
# 1996|Ein Kollektiv-Vertrag ist ein Vertrag für alle Arbeitnehmer in einem Beruf.
#
#
# 775|Bundespräsident Alexander Van der Bellen hat am Montag die Mitglieder der neuen Regierung von Österreich angelobt.
#
#
# 8419|Klima-Volksbegehren startete in Österreich.
#
#
# 11570|Der Höchststand an Arbeitslosen war Mitte April mit 588.000 erreicht worden.
#
#
# 650|Wenn der neue Chef der Konservativen gefunden ist, soll er auch Premier-Minister werden.
#
#
# 7028|London - Der am Corona-Virus erkrankte britische Regierungs-Chef Boris Johnson hat das Krankenhaus verlassen.
#
#
# 2449|Britisches Parlament will harten Brexit verhindern.
#
#
# 11656|Aschbacher trat am Samstag von ihrem Amt zurück.
#
#
# 10475|Im Freien ist ein Treffen von bis zu 12 Personen erlaubt.
#
#
# 8843|Die Corona-Maßnahmen in Österreich wurden eingeführt, damit es möglichst wenige Corona-Fälle gibt.
#
#
# 8720|Die Regierungs-Parteien ÖVP und Grüne lobten diese Maßnahmen.
#
#
# 8747|Eine Million Dollar sind etwas mehr als 880.000 Euro.
#
#
# 10905|Das schätzen Wissenschafter von der Johannes Kepler Universität in Linz.
#
#
# 4035|Besonders die langsamen Koalas können vor dem Feuer nicht davonlaufen.
#
#
# 1617|Die Rakete war 111 Meter hoch und bestand aus mehr als 3 Millionen Teilen.
#
#
# 8648|Dabei handelte es sich um Waffen und Dinge zur Verherrlichung der National-Sozialisten.
#
#
# 8704|Im Tiergarten Schönbrunn in Wien gibt es Nachwuchs bei den Robben.
#
#
# 531|Österreich war aber nicht im Finale.
#
#
# 10430|"Lost" ist das deutsche Jugendwort des Jahres 2020.
#
#
# 4693|Streik von Germanwings-Flugbegleitern in Deutschland.
#
#
# 11253|Damals lagen 709 Corona-Patienten auf Intensiv-Stationen.
#
#
# 12388|Zum Beispiel wird es in den Schlaf-Waggons eigene Toiletten und sogar Dusch-Möglichkeiten geben.
#
#
# 6422|Insgesamt gibt es in China bereits 353 eingereiste Personen, die an dem Corona-Virus erkrankt sind.
#
#
# 8029|Hotels, Pensionen und Campingplätze haben wieder geöffnet.
#
#
# 1203|Aber einer der Orang-Utans nutzt den Schlauch mit den Löchern, um sich mit dem Wasser abzuspritzen.
#
#
# 11460|Allerdings ist ihr Abstand zueinander jedes Mal unterschiedlich groß.
#
#
# 1084|Österreich hat nun Recht bekommen.
#
#
# 6349|Man bekommt aber sein Geld zurück, wenn man zu dieser Zeit nicht zur EM fahren kann.
#
#
# 9316|Im November findet in den USA die Präsidenten-Wahl statt.
#
#
# 10145|Erst am Sonntag sind im US-Bundesstaat Kalifornien wieder 2 neue Waldbrände entstanden.
#
#
# 10703|Derzeit dürfen aus Sicherheitsgründen nur 675 Besucher am Tag.
#
#
# 11061|Nikolo darf trotz Corona-Maßnahmen zu Besuch kommen.
#
#
# 5627|Sie findet nämlich, dass sie selbst und die Partei Vertrauen von möglichst vielen Mitgliedern brauchen.
#
#
# 8096|Noch immer fahren in Wien wenig Menschen mit der U-Bahn.
#
#
# 1027|Im Südsudan ist es üblich, dass Mädchen jung heiraten.
#
#
# 7834|Auch dürfen die Italiener wieder Freunde und Gottesdienste besuchen.
#
#
# 8159|Zwergseidenaffen leben normalerweise im Regenwald von Südamerika.
#
#
# 10903|Alle Schüler müssen also wieder von zu Hause unterrichtet werden.
#
#
# 12203|Heuer werden die Österreicher im Durchschnitt 72 Euro für Valentinstags-Geschenke ausgeben.
#
#
# 8890|Das Fußball-Team Real Madrid ist wieder die Nummer 1 im spanischen Fußball.
#
#
# 8022|Man muss dann nicht mehr überall eine Schutzmaske tragen.
#
#
# 11373|Das wünscht sich der Wiener Gesundheits-Stadtrat Peter Hacker.
#
#
# 6333|Die Corona-Krise wird noch lange dauern.
#
#
# 2265|Jedes Jahr bekommt ihn ein anderer Autor für ein Buch, das er geschrieben hat.
#
#
# 11254|Corona-Impfungen in Großbritannien haben begonnen.
#
#
# 2785|Der Vertrag heißt EU-Mercosur-Abkommen.
#
#
# 12577|Heuer werden die 47 Schlittenhunde-Teams wegen der Corona-Krise etwa bei der Hälfte umdrehen.
#
#
# 12931|Das betrifft den Donaukanal, den Schwedenplatz und den Stephansplatz.
#
#
# 10774|Gesundheitsminister Rudolf Anschober will aber noch keine weiteren Corona-Maßnahmen einführen.
#
#
# 12454|Wie genau diese genutzt werden, bleibt den Schulen überlassen.
#
#
# 11934|Erklärung: Konzentrationslager.
#
#
# 9154|Wegen Hitze, großer Trockenheit und starker Winde breiten sich die Flammen auch noch leicht aus.
#
#
# 10900|Ab Dienstag wird der weiche Lockdown zu einem harten Lockdown geändert.
#
#
# 3456|Nun soll er 70 Meter von der Küste weggerückt werden.
#
#
# 230|Sie lassen nämlich ihre mitgebrachten Kletter-Ausrüstungen am Berg liegen.
#
#
# 9694|Insgesamt sind in Österreich derzeit mehr als 3.400 Menschen mit dem Virus infiziert.
#
#
# 10722|Daher hat man das Personal aufgestockt.
#
#
# 7093|Das hat Kultur-Minister Werner Kogler am Freitag gesagt.
#
#
# 3804|ÖVP und Grüne beschließen Regierungs-Verhandlungen.
#
#
# 3015|Das Flüchtlingslager auf Lesbos ist völlig überfüllt.
#
#
# 11319|Der legendäre Fußball-Trainer Otto Baric ist tot.
#
#
# 1157|Gewonnen hat Ekrem Imamoglu von der Oppositions-Partei CHP.
#
#
# 4142|Ein Notarzt brachte ihn in ein Krankenhaus.
#
#
# 4801|Ein Flugzeug aus der Ukraine ist am Mittwoch in der Früh in der iranischen Hauptstadt Teheran abgestürzt.
#
#
# 2801|Bei der Lotto-Ziehung am Sonntag wartet auf Lotto-Spieler ein Fünffach-Jackpot.
#
#
# 5135|Sie heißt "Die Allianz für Österreich", abgekürzt DAÖ.
#
#
# 11687|Ein Großteil der Ski-Gebiete hatte zu dem Zeitpunkt keine Corona-Maßnahmen entwickelt.
#
#
# 519|In dem Video sieht man FPÖ-Chef und Vizekanzler Heinz-Christian Strache und den FPÖ-Politiker Johann Gudenus.
#
#
# 10618|In Österreich ist die Zahl der Neu-Infektionen mit dem Corona-Virus wieder stark angestiegen.
#
#
# 11692|Zehntausende Benutzer-Konten auf Twitter dauerhaft stillgelegt.
#
#
# 11104|Die Kosten für die Impfungen werden vom Staat Österreich bezahlt.
#
#
# 10927|Das sind rund 37.000 mehr als noch in der Vorwoche.
#
#
# 10439|Seit 17 Jahren liegt der 88-jährige Richter auf Platz 1 im Ranking "Kunstkompass".
#
#
# 12313|Sie sind damit vermutlich besser vor einer erneuten Corona-Erkrankung geschützt.

# %%
short_output_file_name = "data_subset_" + LANGUAGE + "_" + str(SHORT_OUTPUT_DATASET_SIZE) + "_from_" + SOURCE_DATASET + "_" + execution_start_time_string

short_sample = best_set_of_sentences.sample(n=SHORT_OUTPUT_DATASET_SIZE, replace=False)

with open(short_output_file_name, "w") as file:
    counter = 0
    for index, sentence in short_sample.items():
        counter += 1
        file.write(f"{index}|{sentence}\n\n")
        if counter % 100 == 0:
            print(f"{index}|{sentence}\n\n")
# Out:
# 7584|Mit Kleinstaaterei meint Van der Bellen, dass sich jedes EU-Land nur um sich selbst kümmert und keine Rücksicht auf die anderen Länder nimmt.
#
#
# 8596|Das österreichische Außenministerium hat eine Reisewarnung für die Länder des Westbalkans ausgesprochen.

# %%
execution_elapsed_time = time.time() - execution_start_time
print("Code execution completed after ", time.strftime("%H:%M:%S", time.gmtime(execution_elapsed_time)) + f".{int((execution_elapsed_time % 1) * 1000):03d}")
# Out:
# Code execution completed after  00:07:36.640
