# %%
## Imports
import pandas as pd

# %% [markdown]
# **HEADER LEVEL 1**

# %%
## Get the aligned sentences

all_og = df = pd.read_csv('../../../datasets_original/DEPlain/E__Sentence-level_Corpus/DEplain-APA-sent/all.csv')
train_og = df = pd.read_csv('../../../datasets_original/DEPlain/E__Sentence-level_Corpus/DEplain-APA-sent/train.csv')
dev_og = df = pd.read_csv('../../../datasets_original/DEPlain/E__Sentence-level_Corpus/DEplain-APA-sent/dev.csv')
test_og = df = pd.read_csv('../../../datasets_original/DEPlain/E__Sentence-level_Corpus/DEplain-APA-sent/test.csv')
test_w_ref_og = df = pd.read_csv('../../../datasets_original/DEPlain/E__Sentence-level_Corpus/DEplain-APA-sent/test_with_reference.csv')

test_w_ref_og.head()
# Out:
#    Unnamed: 0                                           original  \
# 0         209  Kohlen-Dioxid entsteht, wenn man etwas verbrennt.
# 1         212             Das haben Experten der OECD berechnet.
# 2         216       Die OECD-Länder sind meistens reiche Länder.
# 3         217  Mitglieder sind zum Beispiel Österreich, Deuts...
# 4         243  Das passiert, wenn man eine schwere und anstec...
#
#                                       simplification original_id  \
# 0             Es entsteht, wenn man etwas verbrennt.   628-1-6-3
# 1                   Das sagen Experten von der OECD.   628-1-8-4
# 2  Das sind reiche Länder mit einer guten Wirtsch...  628-1-14-4
# 3  Bei der OECD sind zum Beispiel Österreich, Deu...  628-1-14-2
# 4  Das passiert, wenn man eine schwere und anstec...   629-1-7-2
#
#      simplification_id  pair_id domain            corpus  \
# 0            628-0-6-3      628   news  News Science APA
# 1            628-0-8-6      628   news  News Science APA
# ...

# %%
all_og.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13122 entries, 0 to 13121
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   original                 13122 non-null  object
#  1   simplification           13122 non-null  object
#  2   original_id              13122 non-null  object
#  3   simplification_id        13122 non-null  object
#  4   pair_id                  13122 non-null  int64
#  5   domain                   13122 non-null  object
#  6   corpus                   13122 non-null  object
#  7   language_level_original  13122 non-null  object
#  8   language_level_simple    13122 non-null  object
#  9   license                  13122 non-null  object
#  10  author                   13122 non-null  object
#  11  simple_url               13122 non-null  object
#  12  complex_url              13122 non-null  object
#  13  simple_title             13122 non-null  object
# ...
