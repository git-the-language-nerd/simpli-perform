# %%
## main libraries
import easse
#from lens import download_model, LENS
## others
from collections import OrderedDict
from pprint import pprint
import Levenshtein
#import argilla as rg
from datasets import load_from_disk
import csv
import datetime
import pandas as pd
from datasets import Dataset
import os

# %%
# Use GPU for evaluation, if it is available
import torch
DEVICES = [0] if torch.cuda.is_available() else None

# Quiet PyTorch Lightning logger
import logging, warnings
logging.getLogger("pytorch_lightning.utilities.rank_zero").setLevel(logging.ERROR)
warnings.filterwarnings("ignore")

os.environ['TQDM_DISABLE'] = '1'        # reduce verbosity of lens

# %%
# testing LENS as per the lens-demo

complex = [
    "They are culturally akin to the coastal peoples of Papua New Guinea."
]
simple = [
    "They are culturally similar to the people of Papua New Guinea."
]
references = [[
    "They are culturally similar to the coastal peoples of Papua New Guinea.",
    "They are similar to the Papua New Guinea people living on the coast."
]]



complex2 = [
    "They are culturally akin to the coastal peoples of Papua New Guinea."
]
simple2 = [
    "They are culturally similar to the people of Papua New Guinea."
]
references2 = [[
    "They are culturally similar to the coastal peoples of Papua New Guinea.",
    "They are similar to the Papua New Guinea people living on the coast.",
    "They are culturally similar to the coastal peoples of Papua New Guinea.",
    "They are similar to the Papua New Guinea people living on the coast.",
    "They are culturally similar to the coastal peoples of Papua New Guinea.",
    "They are similar to the Papua New Guinea people living on the coast.",
    "They are culturally similar to the coastal peoples of Papua New Guinea.",
    "They are similar to the Papua New Guinea people living on the coast.",
    "They are culturally similar to the coastal peoples of Papua New Guinea.",
    "They are similar to the Papua New Guinea people living on the coast.",
    "They are culturally similar to the coastal peoples of Papua New Guinea.",
    "They are similar to the Papua New Guinea people living on the coast.",
    "They are culturally similar to the coastal peoples of Papua New Guinea.",
    "They are similar to the Papua New Guinea people living on the coast.",
    "They are culturally similar to the coastal peoples of Papua New Guinea.",
    "They are similar to the Papua New Guinea people living on the coast.",
    "They are culturally similar to the coastal peoples of Papua New Guinea.",
    "They are similar to the Papua New Guinea people living on the coast.",
]]

# %%
# Load LENS
lens_path = download_model("davidheineman/lens")
lens = LENS(lens_path, rescale=True)
# Out:
# Fetching 4 files: 100%|██████████| 4/4 [00:00<00:00, 4814.12it/s]
# Using LENS with topk=3

# %%
# Evaluate the simplification with LENS

scores = lens.score(complex2, simple2, references2, batch_size=16, devices=DEVICES)

print(f'LENS score: {scores}')
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|██████████| 2/2 [00:23<00:00, 11.99s/it]
# LENS score: [78.63447914169828]

# %%
## MY ACTUAL DATA

# %%
languages = ['eng', 'ger', 'fre']
models = ['LLAMA3', 'ChatGPT']
source_datasets = ['EW-SEW', 'DEPlain', 'WiViCo2']
source_dfs = {'eng': None, 'fre': None, 'ger': None}

simplification_files = {
    "eng": [
        "../data_output/english/out_eng_EW-SEW_ChatGPT.csv",
        "../data_output/english/out_eng_EW-SEW_LLAMA3.csv"
    ],
    "fre": [
        "../data_output/french/out_fre_WiViCo2_ChatGPT.csv",
        "../data_output/french/out_fre_WiViCo2_LLAMA3.csv"
    ],
    "ger": [
        "../data_output/german/out_ger_DEPlain_ChatGPT.csv",
        "../data_output/german/out_ger_DEPlain_LLAMA3.csv"
    ]
}

# %%
def parse_file_type_2(input_file, prompt_number=1):

    my_dict = OrderedDict()
    
    if input_file.endswith("txt"):
        print(input_file, "will be passed")
        pass

    else:
        
        my_dict = OrderedDict()
        
        with open(input_file, 'r', encoding='latin1') as file:
            reader = csv.reader(file)
            sentence_number = 1
            current_dict = {}
            prompt = "prompt"+str(prompt_number)
    
            next(reader)  # Skip the first row
            for row in reader:
                if not row[0] :
                    continue
                current_dict["source_index"] = row[0]
                current_dict["input"] = row[1]
                current_dict["output"] = row[prompt_number+1]
                current_dict["prompt"] = row[-1]
                
    
                # calculate sequence matching ratio to find sentence pairs with no or just trivial changes
                current_dict['Lev_distance'] = Levenshtein.distance(current_dict["input"], current_dict["output"])
    
    
                my_dict[sentence_number] = current_dict
                sentence_number += 1
                current_dict = {}

        return my_dict

# %%
argilla_df = pd.read_json('argilla_eval_dataset24-10-08_17h.json')
argilla_df
# Out:
#     language    model model_number source_dataset  \
# 0        eng   LLAMA3       Model1         EW-SEW
# 1        eng   LLAMA3       Model1         EW-SEW
# 2        eng   LLAMA3       Model1         EW-SEW
# 3        eng   LLAMA3       Model1         EW-SEW
# 4        eng   LLAMA3       Model1         EW-SEW
# ..       ...      ...          ...            ...
# 724      fre  ChatGPT       Model2         EW-SEW
# 725      fre  ChatGPT       Model2         EW-SEW
# 726      fre  ChatGPT       Model2         EW-SEW
# 727      fre  ChatGPT       Model2         EW-SEW
# 728      fre  ChatGPT       Model2         EW-SEW
#
#                                        id  \
# 0    e418ccc0-f793-4080-963d-99213295efb3
# 1    640697a4-204f-445a-b8b7-7ed5e4e4fcc0
# 2    c4e9e0cb-df73-4cf5-9b71-453a26e61604
# 3    bc3f564d-6718-4a1d-80cc-87cb9fdf5889
# 4    97b66dfe-eaa2-43ac-9a62-d9b1d203e010
# ..                                    ...
# 724  5bd736ee-2334-42b3-b69b-212965f7646f
# 725  a785fd7b-5170-4582-9ba4-973ea43f8291
# 726  376db04c-3a17-401a-bb38-5521447f9ae1
# 727  ed2f34f6-2862-4add-bdaa-a0e338658e67
# 728  96e0c0e6-ad19-4c55-9ea2-a79db6941ab4
#
#                                      original_sentence  \
# 0    After high school, Carroll attended junior col...
# 1    Many spaniel breeds were developed during the ...
# 2    The song peaked at number six on the Billboard...
# 3    Over the course of the following decade their ...
# 4    In the United States, the sawmill was introduc...
# ..                                                 ...
# 724  Naver est également constamment appelé «Google...
# 725         Il fait suite au jeu Peggle sorti en 2007.
# 726  Power Rangers est une franchise de médias amér...
# 727  Ils étaient initialement cinq, avec Smaïn et S...
# 728  La Bohême (?echy en tchèque, Böhmen en alleman...
#
#                                      modified_sentence  source_index metadata  \
# 0    Carroll attended junior college and then trans...         76021       {}
# 1    Many spaniel breeds were developed in the 19th...          9252       {}
# 2    The song peaked at number six on the Billboard...         75303       {}
# 3    They developed a collaborative working relatio...         25814       {}
# 4    The sawmill was introduced to the United State...         79337       {}
# ..                                                 ...           ...      ...
# 724  Naver est souvent surnommé le "Google de la Co...         36250       {}
# 725      Ce jeu est la suite de Peggle, sorti en 2007.         13480       {}
# 726  Power Rangers est une série de super-héros amé...         38375       {}
# 727  Le groupe initial comprenait cinq membres, don...         13944       {}
# 728  La Bohême est une région historique d'Europe c...         16858       {}
#
#     suggestions   status                            _server_id  \
# 0            {}  pending  3f7c2371-d107-4526-8b57-86480d9a2ccb
# 1            {}  pending  39e95278-f0b9-48ea-a965-c9081a8295bb
# 2            {}  pending  3b590faa-c32f-40b5-9582-18a7d3f7b90b
# 3            {}  pending  f98eaf9f-0849-4a5d-98d7-1978c934dcf5
# 4            {}  pending  d9cc3c03-e8a1-4d38-9707-f33a0042fdd4
# ..          ...      ...                                   ...
# 724          {}  pending  06093ae4-963f-465e-abd2-1fe4b2f44236
# 725          {}  pending  a077935b-0b9a-4693-9280-1b05b97660dc
# 726          {}  pending  96f5e48f-2654-4118-b778-1930fb4190a2
# 727          {}  pending  9f6cfaff-ba83-4487-a8d1-7079c1c33cc3
# 728          {}  pending  9cf38fa0-13a4-4f38-a1fd-d4568b558862
#
#                                   user_id  fluency_rating  adequacy_rating  \
# 0    b06a10e7-e375-4f04-8aac-59295d38d09c              10               10
# 1    b06a10e7-e375-4f04-8aac-59295d38d09c              10                9
# 2    b06a10e7-e375-4f04-8aac-59295d38d09c              10                9
# 3    b06a10e7-e375-4f04-8aac-59295d38d09c              10               10
# 4    b06a10e7-e375-4f04-8aac-59295d38d09c              10                9
# ..                                    ...             ...              ...
# 724  b4f0f6f8-d94f-4738-bfa9-643c4636b565               7                9
# 725  b4f0f6f8-d94f-4738-bfa9-643c4636b565               8               10
# 726  b4f0f6f8-d94f-4738-bfa9-643c4636b565               8                6
# 727  b4f0f6f8-d94f-4738-bfa9-643c4636b565               7               10
# 728  b4f0f6f8-d94f-4738-bfa9-643c4636b565               7                8
#
#      simplicity_rating contains_wrong_information
# 0                   10    No. (Everything's okay)
# 1                   10    No. (Everything's okay)
# 2                    9    No. (Everything's okay)
# 3                   10    No. (Everything's okay)
# 4                   10    No. (Everything's okay)
# ..                 ...                        ...
# 724                  8                       None
# 725                  7                       None
# 726                  8                       None
# 727                  7                       None
# 728                  6                       None
#
# [729 rows x 17 columns]

# %%
### get source datasets

# English

original_sentences_eng_file = '../data_orig/eng/normal.aligned'
simple_sentences_eng_file = '../data_orig/eng/simple.aligned'

original_sents_eng_df = pd.read_csv(original_sentences_eng_file, sep='\t', header=None, names=['unimportant_string_1', 'unimportant_number_1', 'original_sentence'],  encoding='latin1')

# Read the second TSV file
simple_sents_eng_df = pd.read_csv(simple_sentences_eng_file, sep='\t', header=None, names=['unimportant_string_2', 'unimportant_number_2', 'simple_sentence'],  encoding='latin1')

# Extract the relevant columns
original_column = original_sents_eng_df[['original_sentence']]
simple_column = simple_sents_eng_df[['simple_sentence']]

# Combine the DataFrames into one
result_df = pd.concat([original_column, simple_column], axis=1)

source_eng_df = result_df
source_eng_df.rename(columns={'simple_sentence': 'ref_simplifications'}, inplace=True)

source_dfs['eng'] = source_eng_df

source_eng_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167689 entries, 0 to 167688
# Data columns (total 2 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   original_sentence    167689 non-null  object
#  1   ref_simplifications  167689 non-null  object
# dtypes: object(2)
# memory usage: 2.6+ MB

# %%
# French

source_file_french = '../data_orig/fre/wivico_dataset_v2.tsv'
source_fre_df = pd.read_csv(source_file_french, sep='\t', header=None, names=['wiki_sent', 'viki_sent', 'wiki', 'viki', 'pair'], skiprows=[0])
source_fre_df.rename(columns={'wiki_sent': 'original_sentence', 'viki_sent': 'ref_simplifications'}, inplace=True)

source_dfs['fre'] = source_fre_df

source_fre_df
# Out:
#                                        original_sentence  \
# 0      Catharanthus roseus La Pervenche de Madagascar...
# 1      Claude de France (Romorantin, 13 octobre 1499 ...
# 2      Hippocrate de Kos Hippocrate de Kos, ou simple...
# 3      ‌L'ASM Clermont Auvergne, anciennement Associa...
# 4      ‌L'ASM Clermont Auvergne, anciennement Associa...
# ...                                                  ...
# 46520  Өвөр Монгол, Öwör Mongol ; chinois simplifié :...
# 46521  Өвөр Монгол, Öwör Mongol ; chinois simplifié :...
# 46522  Өвөр Монгол, Öwör Mongol ; chinois simplifié :...
# 46523  Өвөр Монгол, Öwör Mongol ; chinois simplifié :...
# 46524  Российские Авиалинии) est la compagnie aérienn...
#
#                                      ref_simplifications  wiki  viki  pair
# 0      La pervenche de Madagascar (nom commun), ou Ca...     0     0     0
# 1      Claude de France est née le 13 octobre 1499 à ...     0     1     0
# 2      Hippocrate de Cos (surnommé Hippocrate le Gran...     0     0     0
# 3      L'ASM Clermont Auvergne, anciennement AS Montf...     0     0     0
# 4      L'ASM Clermont Auvergne, anciennement AS Montf...     0     0     0
# ...                                                  ...   ...   ...   ...
# 46520  Өвөр Монгол, Öwör Mongol ; en chinois : 内蒙古) e...     0     0     0
# 46521  La Région autonome de Mongolie-Intérieure ou s...     0     0     0
# 46522  La Région autonome de Mongolie-Intérieure ou s...     0     0     0
# 46523  La Région autonome de Mongolie-Intérieure ou s...     0     0     0
# 46524  Российские авиалинии, Aèroflot — Rossiyskiye a...     1     1     0
#
# [46525 rows x 5 columns]

# %%
# German
source_file = '../data_orig/ger/all.csv'
source_ger_df = pd.read_csv(source_file)
source_ger_df.rename(columns={'original': 'original_sentence', 'simplification': 'ref_simplifications'}, inplace=True)

source_dfs['ger'] = source_ger_df

source_ger_df
# Out:
#                                        original_sentence  \
# 0      Am Mittwoch hat der Iran bekanntgegeben, dass ...
# 1      Die Präsidentin der EU-Kommission, Ursula von ...
# 2      So sollen die Treibhaus-Gase in der EU bis zum...
# 3      In den letzten 29 Jahren schaffte man eine Ver...
# 4        Für das neue Ziel bleiben weniger als 10 Jahre.
# ...                                                  ...
# 13117  Der Österreicher Adi Hütter ist Trainer von Ei...
# 13118  Er wechselt nach dem Saisonende zu Borussia Mö...
# 13119  Hütter unterschreibt einen Vertrag bis zum Jah...
# 13120  Für Hütter muss Borussia Mönchengladbach auch ...
# 13121  In deutschen Zeitungen wird mit einer Summe vo...
#
#                                      ref_simplifications original_id  \
# 0      Der Iran wird teilweise aus dem Atom-Abkommen ...   296-1-1-0
# 1      Brüssel Ursula von der Leyen ist die Präsident...   628-1-1-0
# 2      Bis zum Jahr 2030 soll es in der EU um 55 Proz...   628-1-1-2
# 3      Das ist sehr viel, denn in den letzten 29 Jahr...   628-1-1-3
# 4      Für das neue Ziel bleiben aber weniger als 10 ...   628-1-1-4
# ...                                                  ...         ...
# 13117  Frankfurt am Main/ Mönchengladbach Adi Hütter ...  769-1-15-0
# 13118  Hütter wird aber mit Saison-Ende in der deutsc...  769-1-15-1
# 13119  Er unterschreibt dort einen Vertrag bis zum Ja...  769-1-15-3
# 13120  Für Hütter muss Mönchengladbach eine hohe Ablö...  769-1-16-0
# 13121  Deutsche Zeitungen rechen mit einer Ablöse von...  769-1-16-1
#
#                                  simplification_id  pair_id domain  \
# 0                                        296-0-1-0      296   news
# 1                    628-0-1-0|628-0-1-1|628-0-1-2      628   news
# 2                                        628-0-1-4      628   news
# 3                                        628-0-1-5      628   news
# 4                                        628-0-1-6      628   news
# ...                                            ...      ...    ...
# 13117  769-0-14-0|769-0-14-1|769-0-14-3|769-0-14-4      769   news
# 13118                        769-0-14-5|769-0-14-7      769   news
# 13119                                   769-0-14-8      769   news
# 13120                                   769-0-15-0      769   news
# 13121                                   769-0-15-1      769   news
#
#                  corpus language_level_original language_level_simple  \
# 0      News Science APA                      b1                    a2
# 1      News Science APA                      b1                    a2
# 2      News Science APA                      b1                    a2
# 3      News Science APA                      b1                    a2
# 4      News Science APA                      b1                    a2
# ...                 ...                     ...                   ...
# 13117  News Science APA                      b1                    a2
# 13118  News Science APA                      b1                    a2
# 13119  News Science APA                      b1                    a2
# 13120  News Science APA                      b1                    a2
# 13121  News Science APA                      b1                    a2
#
#         license                           author  \
# 0      save_use  APA - Austria Presse Agentur eG
# 1      save_use  APA - Austria Presse Agentur eG
# 2      save_use  APA - Austria Presse Agentur eG
# 3      save_use  APA - Austria Presse Agentur eG
# 4      save_use  APA - Austria Presse Agentur eG
# ...         ...                              ...
# 13117  save_use  APA - Austria Presse Agentur eG
# 13118  save_use  APA - Austria Presse Agentur eG
# 13119  save_use  APA - Austria Presse Agentur eG
# 13120  save_use  APA - Austria Presse Agentur eG
# 13121  save_use  APA - Austria Presse Agentur eG
#
#                                               simple_url  \
# 0      https://science.apa.at/nachrichten-leicht-vers...
# 1      https://science.apa.at/nachrichten-leicht-vers...
# 2      https://science.apa.at/nachrichten-leicht-vers...
# 3      https://science.apa.at/nachrichten-leicht-vers...
# 4      https://science.apa.at/nachrichten-leicht-vers...
# ...                                                  ...
# 13117  https://science.apa.at/nachrichten-leicht-vers...
# 13118  https://science.apa.at/nachrichten-leicht-vers...
# 13119  https://science.apa.at/nachrichten-leicht-vers...
# 13120  https://science.apa.at/nachrichten-leicht-vers...
# 13121  https://science.apa.at/nachrichten-leicht-vers...
#
#                                              complex_url  \
# 0      https://science.apa.at/nachrichten-leicht-vers...
# 1      https://science.apa.at/nachrichten-leicht-vers...
# 2      https://science.apa.at/nachrichten-leicht-vers...
# 3      https://science.apa.at/nachrichten-leicht-vers...
# 4      https://science.apa.at/nachrichten-leicht-vers...
# ...                                                  ...
# 13117  https://science.apa.at/nachrichten-leicht-vers...
# 13118  https://science.apa.at/nachrichten-leicht-vers...
# 13119  https://science.apa.at/nachrichten-leicht-vers...
# 13120  https://science.apa.at/nachrichten-leicht-vers...
# 13121  https://science.apa.at/nachrichten-leicht-vers...
#
#                                             simple_title  \
# 0      Nachrichten leicht verständlich (in der Sprach...
# 1      Nachrichten leicht verständlich (in der Sprach...
# 2      Nachrichten leicht verständlich (in der Sprach...
# 3      Nachrichten leicht verständlich (in der Sprach...
# 4      Nachrichten leicht verständlich (in der Sprach...
# ...                                                  ...
# 13117  Nachrichten leicht verständlich (in der Sprach...
# 13118  Nachrichten leicht verständlich (in der Sprach...
# 13119  Nachrichten leicht verständlich (in der Sprach...
# 13120  Nachrichten leicht verständlich (in der Sprach...
# 13121  Nachrichten leicht verständlich (in der Sprach...
#
#                                            complex_title access_date  rater  \
# 0      Nachrichten leicht verständlich (in der Sprach...  2021-04-20      1
# 1      Nachrichten leicht verständlich (in der Sprach...  2021-04-20      1
# 2      Nachrichten leicht verständlich (in der Sprach...  2021-04-20      1
# 3      Nachrichten leicht verständlich (in der Sprach...  2021-04-20      1
# 4      Nachrichten leicht verständlich (in der Sprach...  2021-04-20      1
# ...                                                  ...         ...    ...
# 13117  Nachrichten leicht verständlich (in der Sprach...  2021-04-20      2
# 13118  Nachrichten leicht verständlich (in der Sprach...  2021-04-20      2
# 13119  Nachrichten leicht verständlich (in der Sprach...  2021-04-20      2
# 13120  Nachrichten leicht verständlich (in der Sprach...  2021-04-20      2
# 13121  Nachrichten leicht verständlich (in der Sprach...  2021-04-20      2
#
#       alignment
# 0           1:1
# 1           1:3
# 2           1:1
# 3           1:1
# 4           1:1
# ...         ...
# 13117       1:4
# 13118       1:2
# 13119       1:1
# 13120       1:1
# 13121       1:1
#
# [13122 rows x 18 columns]

# %%
user_mapping = {
    "5d42d341-a876-4707-b069-caf8ed9f8f36": "JW",
    "36985659-71b0-4c64-91a6-f921ad3e6ff2": "AS",
    "26957828-9534-49d7-9c4e-c1ec62ddda1c": "Th",
    "b06a10e7-e375-4f04-8aac-59295d38d09c": "real Al",
    "d84eaa03-d240-4abd-b4eb-d2b8c9d5f6eb": "rw-junk",
    "b4f0f6f8-d94f-4738-bfa9-643c4636b565": "gmx-fan(Nae)",
    "b4219e1a-5bc6-4fbc-b000-284a86c14c9b": "AlA26(Kb)",
    "a61ea0ac-4f34-4eae-a55f-ce8d73823634": "X2",
    "Y2": "language-nerd"
    
}

argilla_df['user'] = argilla_df['user_id'].map(user_mapping)

print(argilla_df["fluency_rating"].value_counts())
print(argilla_df["adequacy_rating"].value_counts())
print(argilla_df["simplicity_rating"].value_counts())
print(argilla_df["language"].value_counts())
print(argilla_df["user_id"].value_counts())
print(argilla_df["simple_sentence"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 14
#       1 user_mapping = {
#       2     "5d42d341-a876-4707-b069-caf8ed9f8f36": "JW",
#       3     "36985659-71b0-4c64-91a6-f921ad3e6ff2": "AS",
#    (...)
#      11
#      12 }
# ---> 14 argilla_df['user'] = argilla_df['user_id'].map(user_mapping)
#      16 print(argilla_df["fluency_rating"].value_counts())
#      17 print(argilla_df["adequacy_rating"].value_counts())
#
# NameError: name 'argilla_df' is not defined

# %%
lens_path = download_model("davidheineman/lens")
lens = LENS(lens_path, rescale=True)

# %%
## ONE LOOP TO MERGE THEM ALL

import easse
import easse.fkgl
import easse.sari
import easse.utils
import easse.utils.preprocessing


DO_NOT_SAVE = False


N = 'all'
BATCH_SIZE = 8     # default: 8


for language in languages:

    for model in models:  
    
        simpli_files_for_language = simplification_files[language]
        for simpli_file in simpli_files_for_language:
            


            if not model in str(simpli_file):
                continue
                

            
            
    
            for l, source_df in source_dfs.items():
                if l != language:
                    continue
                print(f"Now using simpli file-- {simpli_file}")
                print(f"with source_df {source_df} and language {l} and model {model}")
                
                

                merged_df_filename = f"merged_df_{language}_{model}.csv"

                try:
                    merged_df = pd.read_csv(merged_df_filename)
                    print(f"OK. Found and loaded {merged_df_filename}.")
                except FileNotFoundError:
                    print(f"!!! File {merged_df_filename} not found. Will be recreated from sources.")

                    df = pd.read_csv(simpli_file, index_col=0, encoding='latin1')
                    df.rename(columns={'Column1': 'OG_sent'}, inplace=True)
                    df = df.dropna(how='all')

                    
                    merged_df = pd.DataFrame()
                    filtered_df = df[df.index.isin(source_df.index)]
                    merged_df = pd.merge(filtered_df, source_df, left_on='source_index', right_index=True)
                

                complex = merged_df["original_sentence"].fillna("").tolist()
                simple = merged_df["simple_sent(prompt1)"].fillna("").tolist()
                references = [[ref] for ref in merged_df["ref_simplifications"].fillna("")]       # references needs to be a list of lists


                if 'LENS' not in merged_df or merged_df['LENS'].isna().all():
                    # Lens-scoring sentences
                                                
                    lens_scores = []
                    if (not 'N' in globals()) or (type(N) is str):
                        print("Lens-scoring all sentences... Limit N is not set.")
                        lens_scores = lens.score(complex, simple, references, batch_size=BATCH_SIZE, devices=DEVICES)
                    else:  
                        print("Lens-scoring N=", N, " sentences...")
                        
                        lens_scores = lens.score(complex[:N], simple[:N], references[:N], batch_size=BATCH_SIZE, devices=DEVICES)
                        if len(lens_scores) < len(merged_df):
                            lens_scores.extend([""]*(len(merged_df)-len(lens_scores)))

                    merged_df["LENS"] = lens_scores
                else:
                    print("LENS-score already in data.")



                if 'SARI' not in merged_df or merged_df['SARI'].isna().all():
                    # SARI-scoring sentences
                    
                    references_flattened = [[item[0] for item in references]]

                    sari_scores = []
                    if (not 'N' in globals()) or (type(N) is str):
                        print("SARI-scoring all sentences... Limit N is not set.")
                        for i in range(len(complex)):
                            score = easse.sari.corpus_sari(orig_sents=[complex[i]], sys_sents=[simple[i]], refs_sents=references_flattened[0][i])
                            sari_scores.append(score)
                    else:  
                        print("SARI-scoring N=", N, " sentences...")
                        sari_scores = easse.sari.corpus_sari(complex[:N], simple[:N], references_flattened[:N], batch_size=BATCH_SIZE, devices=DEVICES)
                        if len(sari_scores) < len(merged_df):
                            sari_scores.extend([""]*(len(merged_df)-len(sari_scores)))

                    print(sari_scores)
                    merged_df["SARI"] = sari_scores

                else:
                    print("SARI-score already in data.")

                if 'FKGL' not in merged_df or merged_df['FKGL'].isna().all():
                    # FKGL-scoring sentences

                    fkgl_scores = []
                    
                    if (not 'N' in globals()) or (type(N) is str):
                        simple = simple
                        print("FKGL-scoring all sentences... Limit N is not set.")   
                    else:
                        simple = simple[:N]
                        print("SARI-scoring N=", N, " sentences...")   
                        
                    for i, sentence in enumerate(simple):
                        scorer = easse.fkgl.FKGLScorer()
                        scorer.add(easse.utils.preprocessing.normalize(sentence, tokenizer="13a"))
                        fkgl_scores.append(scorer.score())                                   

                    print(fkgl_scores)
                    merged_df["FKGL"] = fkgl_scores
    
                if not DO_NOT_SAVE:
                    print("TEST")
                    merged_df["source_index"] = merged_df["source_index"].astype(int)
                    merged_df.to_csv(merged_df_filename, index=False)
                
                print("Finished processing ", language, model)
                print("______")

print("|||||| ALL DONE ||||||")

merged_df
# Out:
# Now using simpli file-- ../data_output/english/out_eng_EW-SEW_LLAMA3.csv
# with source_df None and language eng and model LLAMA3
# OK. Found and loaded merged_df_eng_LLAMA3.csv.
# LENS-score already in data.
# SARI-score already in data.
# TEST
# Finished processing  eng LLAMA3
# ______
# Now using simpli file-- ../data_output/english/out_eng_EW-SEW_ChatGPT.csv
# with source_df None and language eng and model ChatGPT
# OK. Found and loaded merged_df_eng_ChatGPT.csv.
# LENS-score already in data.
# SARI-score already in data.
# TEST
# Finished processing  eng ChatGPT
# ______
# Now using simpli file-- ../data_output/german/out_ger_DEPlain_LLAMA3.csv
# with source_df None and language ger and model LLAMA3
# OK. Found and loaded merged_df_ger_LLAMA3.csv.
# LENS-score already in data.
# SARI-score already in data.
# TEST
# Finished processing  ger LLAMA3
# ______
# Now using simpli file-- ../data_output/german/out_ger_DEPlain_ChatGPT.csv
# with source_df None and language ger and model ChatGPT
# OK. Found and loaded merged_df_ger_ChatGPT.csv.
# LENS-score already in data.
# SARI-score already in data.
# TEST
# Finished processing  ger ChatGPT
# ______
# Now using simpli file-- ../data_output/french/out_fre_WiViCo2_LLAMA3.csv
# with source_df None and language fre and model LLAMA3
# OK. Found and loaded merged_df_fre_LLAMA3.csv.
# LENS-score already in data.
# SARI-score already in data.
# TEST
# Finished processing  fre LLAMA3
# ______
# Now using simpli file-- ../data_output/french/out_fre_WiViCo2_ChatGPT.csv
# with source_df None and language fre and model ChatGPT
# OK. Found and loaded merged_df_fre_ChatGPT.csv.
# LENS-score already in data.
# SARI-score already in data.
# TEST
# Finished processing  fre ChatGPT
# ______
# |||||| ALL DONE ||||||
#       source_index                                            OG_sent  \
# 0            37241  Panurus biarmicus La Panure à moustaches (Panu...
# 1            35958  Monsieur Wens, surnom de Wenceslas Vorobeïtchi...
# 2            13955  Ils permettent aux enfants de s'amuser en fais...
# 3            39745  Saint-Ignace-de-Loyola est une municipalité du...
# 4            25619  Le hanafisme ou hanéfisme (en arabe : ????, ?a...
# ...            ...                                                ...
# 1095         42801  Un banc est un groupement important de poisson...
# 1096         44032  Un satellite de reconnaissance, ou satellite e...
# 1097         38504  Progressistes (en portugais : Progressistas) ...
# 1098         28169  Le pop rock est un genre musical mêlant le sty...
# 1099         41130  Spider-Man est depuis lors l'un des personnage...
#
#                                    simple_sent(prompt1)  simple_sent(prompt2)  \
# 0     La Panure à moustaches est un oiseau d'Europe,...                   NaN
# 1     Monsieur Wens est un personnage de roman polic...                   NaN
# 2     Les enfants s'amusent en construisant des chât...                   NaN
# 3     Saint-Ignace-de-Loyola est une ville du Québec...                   NaN
# 4     Le hanafisme est l'une des plus anciennes écol...                   NaN
# ...                                                 ...                   ...
# 1095  Un banc est un groupe de poissons de la même e...                   NaN
# 1096  Un satellite espion est un satellite utilisé p...                   NaN
# 1097  Les Progressistes sont un parti politique brés...                   NaN
# 1098  Le pop rock est un genre de musique qui mélang...                   NaN
# 1099  Spider-Man est un personnage très populaire da...                   NaN
#
#                                                 Prompt1  Prompt2       Model  \
# 0     Convertis chacune de ces 50 phrases originales...      NaN  ChatGPT-4o
# 1     Convertis chacune de ces 50 phrases originales...      NaN  ChatGPT-4o
# 2     Convertis chacune de ces 50 phrases originales...      NaN  ChatGPT-4o
# 3     Convertis chacune de ces 50 phrases originales...      NaN  ChatGPT-4o
# 4     Convertis chacune de ces 50 phrases originales...      NaN  ChatGPT-4o
# ...                                                 ...      ...         ...
# 1095  Convertis chacune de ces 50 phrases originales...      NaN  ChatGPT-4o
# 1096  Convertis chacune de ces 50 phrases originales...      NaN  ChatGPT-4o
# 1097  Convertis chacune de ces 50 phrases originales...      NaN  ChatGPT-4o
# 1098  Convertis chacune de ces 50 phrases originales...      NaN  ChatGPT-4o
# 1099  Convertis chacune de ces 50 phrases originales...      NaN  ChatGPT-4o
#
#                                       original_sentence  \
# 0     Panurus biarmicus La Panure à moustaches (Panu...
# 1     Monsieur Wens, surnom de Wenceslas Vorobeïtchi...
# 2     Ils permettent aux enfants de s'amuser en fais...
# 3     Saint-Ignace-de-Loyola est une municipalité du...
# 4     Le hanafisme ou hanéfisme (en arabe : حنفي, Ḥa...
# ...                                                 ...
# 1095  Un banc est un groupement important de poisson...
# 1096  Un satellite de reconnaissance, ou satellite e...
# 1097  Progressistes (en portugais : Progressistas) —...
# 1098  Le pop rock est un genre musical mêlant le sty...
# 1099  Spider-Man est depuis lors l'un des personnage...
#
#                                     ref_simplifications  wiki  viki  pair  \
# 0     La panure à moustaches est un passereau d'Eura...     0     1     0
# 1      Monsieur Wens est un personnage de fiction cr...     0     1     0
# 2     Il permet aux enfants de s'amuser en faisant d...     0     1     0
# 3     Saint-Ignace-de-Loyola est une petite municipa...     0     1     0
# 4     On parle aussi d'écoles juridiques, car ces éc...     0     1     0
# ...                                                 ...   ...   ...   ...
# 1095  Un banc de poissons est un grand groupe de poi...     0     1     0
# 1096  Un  satellite de reconnaissance  (satellite es...     0     1     0
# 1097    Progressistas est un parti politique au Brésil.     0     1     0
# 1098  Le pop rock est un genre musical dérivé du roc...     0     1     0
# 1099  Spider-Man (l'homme araignée) est un personnag...     0     1     0
#
#            LENS       SARI       FKGL
# 0     53.301664  30.519752   3.620000
# 1     47.054342  16.841231   8.392941
# 2     53.916683  28.400285   9.209474
# 3     58.769179  26.271023   8.392941
# 4     50.990206  32.033778   7.633846
# ...         ...        ...        ...
# 1095  48.346710  23.302169   2.060000
# 1096  62.954711  27.145712  11.500000
# 1097  70.639613  29.684792   5.818462
# 1098  63.847101  28.692151   0.827143
# 1099  73.422657  31.790240   8.009091
#
# [1100 rows x 15 columns]
